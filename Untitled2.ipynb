# %%
#Area de declaracion de variable
var_pro_int_conCic = 0
var_pro_int_finCic = 0

# %%
for var_pro_int_conCic in range(10):
  print("usted va en la vuelta", var_pro_int_conCic)
# Out:
# usted va en la vuelta 0
# usted va en la vuelta 1
# usted va en la vuelta 2
# usted va en la vuelta 3
# usted va en la vuelta 4
# usted va en la vuelta 5
# usted va en la vuelta 6
# usted va en la vuelta 7
# usted va en la vuelta 8
# usted va en la vuelta 9

# %%
# Ciclo para leyendo inicio y el fin
var_pro_int_Concic = int(input("Digite inicio del ciclo : "))
var_pro_int_finCic = int(input("Digite fin del ciclo : "))
# Ciclo for 2
for var_pro_int_Concic in range(var_pro_int_conCic):
  print(var_pro_int_conCic)
# Out:
# Digite inicio del ciclo : 5
# Digite fin del ciclo : 10
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9

# %%
# Leer cuantos numeros voy a leer, se suman y promedian 
numero = 0
suma = 0
promedio=0,0
cantidad = int(input("Digite cantidad de numeros : "))
for i in range(cantidad):
  numero = int(input("Digite un numero : "))
  suma = suma+numero
print("la suma es : " ,suma)
promedio=suma/cantidad
print (promedio)
# Out:
# Digite cantidad de numeros : 3
# Digite un numero : 4
# Digite un numero : 8
# Digite un numero : 12
# la suma es :  24
# 8.0
