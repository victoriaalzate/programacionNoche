# %%
#punto 1
suma=0
numero_uno=int(input("ingrese primer numero : "))
incremento=int(input("ingrese el incremento del numero"))
numero_2=int(input("ingrese numero final"))
suma=suma+1
for x in range(numero_uno,suma,numero_2,incremento):
  print(x)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-f7465cacb886> in <module>
#       2 suma=0
#       3 numero_uno=int(input("ingrese primer numero : "))
# ----> 4 incremento=int(input("ingrese el incremento del numero"))
#       5 numero_2=int(input("ingrese numero final"))
#       6 suma=suma+1
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# ...
