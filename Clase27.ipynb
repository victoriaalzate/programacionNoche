# %%
---
Programa: Calculo del factorial de un numero
Autor: Victoria Alzate
Version: 1.0
Fecha: 17_09_2022
"""

# %%
#Declaras variables
num=0
fac=1
#Lecturas
num= int(input("Digite número : "))
#Proceso
for i in range(1,num+1):
  fac = fac * i

# Imprimir resultados
print("El factorial es: ",str(fac))
# Out:
# Digite número : 4
# El factorial es:  24

# %%
###
import math
num = int(input("Digite número : "))
print("El factorial es : ",str(math.factorial(num)))
# Out:
# Digite número : 4
# El factorial es :  24

# %%
def miFactorial():
 num=0
 fac=1
 #Lecturas
 num= int(input("Digite número : "))
 #Proceso
 for i in range(1,num+1):
  fac = fac * i

 # Imprimir resultados
 print("El factorial es: ",str(fac))

 # Llamado de mi funcion
miFactorial()
miFactorial()
