# %%
# Ciclo para 5
for x in range(5):
    print(x)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# Ciclo para 6
for x in range(1,5):
    print(x)
# Out:
# 1
# 2
# 3
# 4

# %%
# Ciclo para 6
for x in range(1,5):
    print(x)
# Out:
# 1
# 2
# 3
# 4

# %%
# Ciclo para 7
for x in range(100,200,2):
    print(x)
# Out:
# 100
# 102
# 104
# 106
# 108
# 110
# 112
# 114
# 116
# 118
# 120
# 122
# 124
# 126
# 128
# 130
# 132
# 134
# 136
# 138
# 140
# 142
# 144
# 146
# 148
# 150
# 152
# 154
# 156
# 158
# 160
# 162
# 164
# 166
# 168
# 170
# 172
# 174
# 176
# 178
# 180
# 182
# 184
# 186
# 188
# 190
# 192
# 194
# 196
# 198

# %%
# Ciclo 8
# Ciclo para 6
inicio= int(input("Inicio : "))
fin= int(input("Fin : "))
incremento = int(input("incremento : "))
for x in range(inicio,fin,incremento):
    print(x)
# Out:
# Inicio : 100
# Fin : 80
# incremento : -5
# 100
# 95
# 90
# 85

# %%
# Tabla de multiplicar de un numero
mult=0
x=0
tabla = int(input("Que tabla desea : "))
for x in range(1,11):
    mult = tabla * x
    print("La respuesta es : ",mult)
# Out:
# Que tabla desea : 5
# La respuesta es :  5
# La respuesta es :  10
# La respuesta es :  15
# La respuesta es :  20
# La respuesta es :  25
# La respuesta es :  30
# La respuesta es :  35
# La respuesta es :  40
# La respuesta es :  45
# La respuesta es :  50

# %%
# Tabla de multiplicar de un numero
mult=0
x=0
tabla = int(input("Que tabla desea : "))
for x in range(1,11):
    mult = tabla * x
    print(tabla,"*",x,"=",mult)
# Out:
# Que tabla desea : 5
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50

# %%
# Tabla de multiplicar de un numero
mult=0
tabla = int(input("Que tabla desea : "))
for x in range(1,11):
    mult = tabla * x
 
    x=1
    while x<=11:
       print(tabla,"*",x,"=",mult)
# Out:
#   File "<ipython-input-31-7bec18a34a01>", line 4
#     mult = tabla * x
#     ^
# IndentationError: unexpected indent
