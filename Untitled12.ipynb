# %%
class Cachorro():
    # Metodo Constructor
    def __init__(self, p_color, p_raza, p_nolmbre):
      self.color = p_color
      self.raza = p_raza
      self.nombre = p_nombre

# Modulo Principal
p_color = input("Color : ")
p_raza = input("Raza : ")
p_nombre = input("Nombre : ")

perrito = Cachorro(p_color,p_raza,p_nombre)
print("Este es un cachorro sin dueño y la raza ")
