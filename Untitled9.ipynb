# %%
#Funciones de manejo de cadenas
mensaje1 = "Hola" + ' ' + "Mundo"
print(mensaje1)

nombre =''
apellido =''
nombreCompleto = ''

nombre = input("Digite Nombre: ")
apellido = input("Digite Apellido: ")

nombreCompleto = nombre+ " " +apellido
print("Su nombre completo es : ",nombreCompleto)
# Out:
# Hola Mundo
# Digite Nombre: Victoria
# Digite Apellido: Alzate
# Su nombre completo es :  Victoria Alzate

# %%
#
mensaje4 = "Hola" + ' ' + "Mundo Maravilloso"
print(len(mensaje4))
# Out:
# 22

# %%
mensaje2a = 'Hola ' * 5
mensaje2b = 'Mundo'
print(mensaje2a + mensaje2b)
# Out:
# Hola Hola Hola Hola Hola Mundo

# %%
mensaje5 = "Hola Mundo"
mensaje5a = mensaje5.find("Mundo")
print(mensaje5a)
# Out:
# 5

# %%
# Desarrollo de la función
def buscarPosCad(texto,buscar):
  pos=texto.find(buscar)
  return pos 

# Cadena de datos

textoLeer = input ("Digite cadena origen : ")
textoLeer = textoLeer.lower()
textoBuscar = input ("Digite texto a buscar : ")
textoBuscar = textoBuscar.lower()

# Llamado de la función
res = buscarPosCad(textoLeer,textoBuscar)

if res >=0 :
  print ("Posición : ",str(res+1))
else:
  print("El texto buscado no existe en la cadena ")
# Out:
# Digite cadena origen : Victoria
# Digite texto a buscar : v
# Posición :  1

# %%
mensaje7 = "VICTORIA"
mensaje7a = mensaje7.lower()
print(mensaje7a)
# Out:
# victoria

# %%
mensaje8 = "HOLA-MUNDO- "
mensaje8a = mensaje8.replace(" ", "MARAVILLOSO")
print(mensaje8a)
# Out:
# HOLA-MUNDO-MARAVILLOSO

# %%
mensaje9 = "Hola Mundo"
mensaje9a = mensaje9[1:8]
print(mensaje9a)
# Out:
# ola Mun

# %%
mensaje9 = "Hola Mundo"
startLoc = 2 
endLoc = 8 
mensaje9b = mensaje9[startLoc: endLoc]
print(mensaje9b)
# Out:
# la Mun

# %%
mensaje9 = "Hola Mundo"
print(mensaje9[:].find("d"))
# Out:
# 8
