# %%
#Desarrollo de la funcion

def Ult_Dig(Num):
  UltDig = 0
  UltDig = Num%10
  return(UltDig)

# Llamado de la funcion

valor = int(input("Digite el numero : "))
print("El ultimo Digito es : ", Ult_Dig(valor))
# Out:
# Digite el numero : 158
# El ultimo Digito es :  8

# %%
#Desarrollo de la funcion

def Ult_Dig(Num):
  UltDig = 0
  UltDig = Num%100
  return(UltDig)

# Llamado de la funcion


print("El ultimo Digito es : ", Ult_Dig(int(input("Digite el numero : "))))
# Out:
# Digite el numero : 123
# El ultimo Digito es :  23
